# %% [markdown]
# # Lab cleaning categorical data

# %% [markdown]
# ## Import libraries

# %% [markdown]
# 1. Import the necessary libraries if you are starting a new notebook.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ##  Get data

# %% [markdown]
# 2. Load the csv. Use the variable customer_df as customer_df = pd.read_csv().

# %%
customer_df = pd.read_csv('./files_for_lab/we_fn_use_c_marketing_customer_value_analysis.csv')

# %%
customer_df.head()
# Out:
#   Customer       State  Customer Lifetime Value Response  Coverage Education
# 0  BU79786  Washington              2763.519279       No     Basic  Bachelor  \
# 1  QZ44356     Arizona              6979.535903       No  Extended  Bachelor
# 2  AI49188      Nevada             12887.431650       No   Premium  Bachelor
# 3  WW63253  California              7645.861827       No     Basic  Bachelor
# 4  HB64268  Washington              2813.692575       No     Basic  Bachelor
#
#   Effective To Date EmploymentStatus Gender  Income  ...
# 0           2/24/11         Employed      F   56274  ...  \
# 1           1/31/11       Unemployed      F       0  ...
# 2           2/19/11         Employed      F   48767  ...
# 3           1/20/11       Unemployed      M       0  ...
# 4            2/3/11         Employed      M   43836  ...
#
#   Months Since Policy Inception Number of Open Complaints  Number of Policies
# ...

# %% [markdown]
# 3. What should we do with the customer_id column?

# %% [markdown]
# * Customer ID is just an identifier that doesn't give us any valuable information for this use case, that's why I will drop it.

# %%
customer_df.columns
# Out:
# Index(['Customer', 'State', 'Customer Lifetime Value', 'Response', 'Coverage',
#        'Education', 'Effective To Date', 'EmploymentStatus', 'Gender',
#        'Income', 'Location Code', 'Marital Status', 'Monthly Premium Auto',
#        'Months Since Last Claim', 'Months Since Policy Inception',
#        'Number of Open Complaints', 'Number of Policies', 'Policy Type',
#        'Policy', 'Renew Offer Type', 'Sales Channel', 'Total Claim Amount',
#        'Vehicle Class', 'Vehicle Size'],
#       dtype='object')

# %%
customer_df.columns = customer_df.columns.str.lower().str.replace(' ', '_')

# %%
customer_df.columns
# Out:
# Index(['customer', 'state', 'customer_lifetime_value', 'response', 'coverage',
#        'education', 'effective_to_date', 'employmentstatus', 'gender',
#        'income', 'location_code', 'marital_status', 'monthly_premium_auto',
#        'months_since_last_claim', 'months_since_policy_inception',
#        'number_of_open_complaints', 'number_of_policies', 'policy_type',
#        'policy', 'renew_offer_type', 'sales_channel', 'total_claim_amount',
#        'vehicle_class', 'vehicle_size'],
#       dtype='object')

# %%
customer_df.drop(columns=['customer'], inplace=True)

# %%
customer_df.head()
# Out:
#         state  customer_lifetime_value response  coverage education
# 0  Washington              2763.519279       No     Basic  Bachelor  \
# 1     Arizona              6979.535903       No  Extended  Bachelor
# 2      Nevada             12887.431650       No   Premium  Bachelor
# 3  California              7645.861827       No     Basic  Bachelor
# 4  Washington              2813.692575       No     Basic  Bachelor
#
#   effective_to_date employmentstatus gender  income location_code  ...
# 0           2/24/11         Employed      F   56274      Suburban  ...  \
# 1           1/31/11       Unemployed      F       0      Suburban  ...
# 2           2/19/11         Employed      F   48767      Suburban  ...
# 3           1/20/11       Unemployed      M       0      Suburban  ...
# 4            2/3/11         Employed      M   43836         Rural  ...
#
#   months_since_policy_inception  number_of_open_complaints
# 0                             5                          0  \
# ...

# %% [markdown]
# ## Split dataframe into categorical and numerical data

# %% [markdown]
# 4. Load the continuous and discrete variables into numericals_df and categorical_df variables

# %%
numerical_df = customer_df.select_dtypes(np.number)

# %%
categorical_df = customer_df.select_dtypes(object)

# %%
numerical_df.columns
# Out:
# Index(['customer_lifetime_value', 'income', 'monthly_premium_auto',
#        'months_since_last_claim', 'months_since_policy_inception',
#        'number_of_open_complaints', 'number_of_policies',
#        'total_claim_amount'],
#       dtype='object')

# %%
numerical_df.shape
# Out:
# (9134, 8)

# %%
categorical_df.columns
# Out:
# Index(['state', 'response', 'coverage', 'education', 'effective_to_date',
#        'employmentstatus', 'gender', 'location_code', 'marital_status',
#        'policy_type', 'policy', 'renew_offer_type', 'sales_channel',
#        'vehicle_class', 'vehicle_size'],
#       dtype='object')

# %%
categorical_df.shape
# Out:
# (9134, 15)

# %% [markdown]
# ## Plot categorical data

# %% [markdown]
# 5. Plot every categorical variable. What can you see in the plots? Note that in the previous lab you used a bar plot to plot categorical data, with each unique category in the column on the x-axis and an appropriate measure on the y-axis. However, this time you will try a different plot. This time in each plot for the categorical variable you will have, each unique category in the column on the x-axis and the target(which is numerical) on the Y-axis

# %%
for column in categorical_df.columns:
    sns.barplot(x = categorical_df[column], y = customer_df['total_claim_amount'], errorbar=None)
    plt.xticks( rotation = 45)
    plt.show()

# %% [markdown]
# * We can see each categorical feature distribution vs our target (total_claim_amount)

# %% [markdown]
# ## Data cleaning (categorical only)

# %% [markdown]
# 6. For the categorical data, check if there is any data cleaning that need to perform. Hint: You can use the function value_counts() on each of the categorical columns and check the representation of different categories in each column. Discuss if this information might in some way be used for data cleaning.

# %%
categorical_df.columns
# Out:
# Index(['state', 'response', 'coverage', 'education', 'effective_to_date',
#        'employmentstatus', 'gender', 'location_code', 'marital_status',
#        'policy_type', 'policy', 'renew_offer_type', 'sales_channel',
#        'vehicle_class', 'vehicle_size'],
#       dtype='object')

# %%
for column in categorical_df.drop(columns = ['effective_to_date']).columns:
    print(f'Value counts for {column}: {categorical_df[column].value_counts(dropna=False)}')
    print('-----------------------------------------------------')
# Out:
# Value counts for state: state
# California    3150
# Oregon        2601
# Arizona       1703
# Nevada         882
# Washington     798
# Name: count, dtype: int64
# -----------------------------------------------------
# Value counts for response: response
# No     7826
# Yes    1308
# Name: count, dtype: int64
# -----------------------------------------------------
# Value counts for coverage: coverage
# Basic       5568
# Extended    2742
# Premium      824
# Name: count, dtype: int64
# -----------------------------------------------------
# Value counts for education: education
# Bachelor                2748
# College                 2681
# High School or Below    2622
# Master                   741
# Doctor                   342
# Name: count, dtype: int64
# -----------------------------------------------------
# Value counts for employmentstatus: employmentstatus
# Employed         5698
# Unemployed       2317
# Medical Leave     432
# Disabled          405
# ...

# %% [markdown]
# * All categorical data it's ok, don'´t need any aditional cleaning, maybe we can get more info from effective_to_date column like month or year.
